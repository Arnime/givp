# %% [markdown]
# # GIVP Julia × balanço hídrico sintético
#
# O notebook executa o GIVP nativo Julia e usa o worker Python somente para a física.

# %%
root = abspath(ENV["GIVP_ROOT"])
definition = joinpath(root, "experiments", "synthetic_hydropower", "interop", "v1", "optimization_definition.json")
demo = joinpath(root, "experiments", "synthetic_hydropower", "clients", "julia", "optimize.jl")
run(`julia --project=$(joinpath(root, "julia")) $demo $definition`)
