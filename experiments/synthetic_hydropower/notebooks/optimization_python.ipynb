# %% [markdown]
# # GIVP Python × balanço hídrico sintético
#
# Este experimento otimiza 48 potências horárias e reavalia a agenda pelo mesmo protocolo físico canônico.

# %%
import os
import subprocess
import sys
from pathlib import Path

root = Path(os.environ['GIVP_ROOT']).resolve()
definition = root / 'experiments' / 'synthetic_hydropower' / 'interop' / 'v1' / 'optimization_definition.json'
demo = root / 'experiments' / 'synthetic_hydropower' / 'clients' / 'python' / 'optimize.py'
completed = subprocess.run([sys.executable, str(demo), str(definition)], check=True, capture_output=True, text=True)
print(completed.stdout)
