# %% [markdown]
# # GIVP R × balanço hídrico sintético
#
# O otimizador R mantém um worker Python persistente e minimiza o objetivo hidráulico canônico.

# %%
root <- normalizePath(Sys.getenv('GIVP_ROOT'))
definition <- file.path(root, 'experiments', 'synthetic_hydropower', 'interop', 'v1', 'optimization_definition.json')
demo <- file.path(root, 'experiments', 'synthetic_hydropower', 'clients', 'r', 'optimize.R')
system2('Rscript', c(demo, definition))
